# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 3

# %%
from processing import *

# %%
from plot_helpers import *

# %%
default_rcParams()
plot_energy('/scratch/pp2681/NEMO-data/Reynolds/CR_20/GYRE_1d_00010101_00301230_series_energy.nc')

# %%
plot_surf_EKE('/scratch/pp2681/NEMO-data/Reynolds/CR_25_2iter/GYRE_360d_00010101_00301230_ocean.nc')
# Out:
# /scratch/pp2681/NEMO-data/Reynolds/CR_25_2iter/GYRE_360d_00010101_00301230_ocean.nc

# %%
plot_z_EKE('/scratch/pp2681/NEMO-data/Reynolds/CR_25_2iter/GYRE_360d_00010101_00301230_ocean.nc', 'mesh_mask_R4.nc')

# %%
plot_SST('/scratch/pp2681/NEMO-data/Reynolds/CR_20/GYRE_360d_00010101_00301230_ocean.nc')

# %%
plot_snapshot_vorticity('/scratch/pp2681/NEMO-data/Reynolds/CR_20/GYRE_5d_00010101_00301230_surf.nc')

# %%
plot_flux_meridional('/scratch/pp2681/NEMO-data/Reynolds/CR_25_2iter/GYRE_360d_00010101_00301230_ocean.nc', 'mesh_mask_R4.nc')

# %%
plot_flux_MOC('/scratch/pp2681/NEMO-data/Reynolds/CR_20/GYRE_360d_00010101_00301230_ocean.nc', 'mesh_mask_R4.nc')

# %% [markdown]
# # Class experiment development

# %%
from experiment import *

# %%
base_folder = '/scratch/pp2681/NEMO-data/'

# %%
exp = Experiment(base_folder+'/EXPR9_100')

# %%
exp.test_flux()
# Out:
# Typical value should be 1e-7,  9.028198018624933e-07

# %%
exp.plot_2D('vabs', vmax=0.5)
# Out:
# (80, 120)

# %%
exp.plot_EKE()

# %%
exp.plot_EKEmean()
# Out:
# (80, 120)

# %%
exp.plot_EKEz()

# %%
exp.plot_SST()

# %%
exp.plot_MOC_heat()
plt.savefig('MOC_heat_R9.pdf')

# %%
exp.heat_flux.plot(label='R9')
plt.legend()
